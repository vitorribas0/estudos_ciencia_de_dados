# %% [markdown]
# # Naive Bayes - Explicação Simples
#
# **Naive Bayes** é um algoritmo de classificação baseado em probabilidades que usa o Teorema de Bayes.
#
# ## Como funciona?
#
# 1. **Aprende com exemplos**: calcula probabilidades de cada característica para cada classe
# 2. **Faz previsões**: multiplica as probabilidades e escolhe a classe com maior valor
# 3. **Assume independência**: trata cada característica como independente (por isso "naive" = ingênuo)
#
# ## Fórmula:
# $$P(\text{Classe} | \text{Características}) \propto P(\text{Características} | \text{Classe}) \times P(\text{Classe})$$
#
# ## Exemplo deste notebook:
# Vamos prever se alguém tem **diabetes** baseado em:
# - Atividade física
# - Acima do peso
# - Histórico familiar

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.naive_bayes import GaussianNB

# %%
df = pd.DataFrame(
    {
        "atividade fisica": [1, 0, 0, 0, 1, 1, 0],
        "acima do peso": [1, 1, 1, 0, 0, 1, 0],
        "historico familiar": [1, 1, 0, 1, 1, 0, 0],
        "diabetes": [1, 1, 1, 1, 0, 0, 0],
    }
)
df.head()
# Out:
#    atividade fisica  acima do peso  historico familiar  diabetes
# 0                 1              1                   1         1
# 1                 0              1                   1         1
# 2                 0              1                   0         1
# 3                 0              0                   1         1
# 4                 1              0                   1         0

# %% [markdown]
# ## Treinando o Modelo

# %%
# Separar características (X) e alvo (y)
X = df[["atividade fisica", "acima do peso", "historico familiar"]]
y = df["diabetes"]

# Criar e treinar o modelo
modelo = GaussianNB()
modelo.fit(X, y)
# Out:
# GaussianNB()

# %% [markdown]
# ## Fazendo Previsões

# %%
# Novo paciente: [ativ_fisica, acima_peso, hist_familiar]
novo_paciente = [[0, 1, 1]]  # Não faz atividade, acima do peso, tem histórico

# Prever se tem diabetes
previsao = modelo.predict(novo_paciente)
probabilidades = modelo.predict_proba(novo_paciente)

print(f"Previsão: {'TEM diabetes' if previsao[0] == 1 else 'NÃO tem diabetes'}")
print(f"Probabilidades: Não={probabilidades[0][0]:.2%}, Sim={probabilidades[0][1]:.2%}")
# Out:
# Previsão: TEM diabetes
# Probabilidades: Não=4.55%, Sim=95.45%
# c:\Users\vitor\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# c:\Users\vitor\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Papel de pão 🍞
#
# - **Sobre o algoritmo:**
#     - **Motivação e conceito**: algoritmo probabilístico baseado no Teorema de Bayes para classificação, que calcula a probabilidade de um dado pertencer a cada classe e escolhe a mais provável
#     - **Exemplo**: filtro de spam - calcula P(Spam | palavras) e P(Normal | palavras) para classificar emails
#     - **Como funciona?**
#         - Fase de treino: calcula probabilidades a priori P(Classe) e probabilidades condicionais P(Feature|Classe)
#         - Fase de predição: aplica Teorema de Bayes para cada classe e escolhe a de maior probabilidade
#         - Fórmula: $P(Classe|X) = \frac{P(X|Classe) \times P(Classe)}{P(X)}$
#     - **Pseudocódigo:**
#         ```
#         Treino:
#             Para cada classe c:
#                 Calcular P(c) = quantidade_c / total
#                 Para cada feature f:
#                     Calcular P(f|c) usando distribuição apropriada
#
#         Predição:
#             Para cada classe c:
#                 score[c] = P(c)
#                 Para cada feature f:
#                     score[c] *= P(f|c)
#             Retornar classe com maior score
#         ```
#     - **Tipos de Naive Bayes:**
#         - **GaussianNB**: features contínuas com distribuição normal
#         - **MultinomialNB**: contagem de frequências (texto, palavras)
#         - **BernoulliNB**: features binárias (0 ou 1)
#         - **ComplementNB**: para datasets desbalanceados
#     - **Suavização (Smoothing)**:
#         - Laplace smoothing: evita probabilidade zero para features não vistas
#         - Adiciona um pequeno valor (alpha) às contagens
#
# - **Conclusões sobre o apresentado:**
#     - Aceita variáveis numéricas e categóricas (depende do tipo)
#     - Algoritmo **parametrizado** (aprende parâmetros como média e variância)
#     - **Eager learning** (aprende na fase de treino)
#     - Baseado em probabilidades
#     - Complexidade linear O(n×m) - n amostras, m features
#     - Assume **independência entre features** (naive = ingênuo)
#
# - **Outliers impactam:**
#     - Afetam cálculo de média e variância (GaussianNB)
#     - Podem distorcer probabilidades condicionais
#     - Solução: pré-processamento e remoção de outliers
#
# - **Normalização:**
#     - GaussianNB: **não obrigatório**, pois trabalha com probabilidades
#     - Pode trazer benefícios para convergência e estabilidade numérica
#     - Importante quando features têm escalas muito diferentes
#
# - **Vantagens:**
#     - Rápido para treinar e prever
#     - Funciona bem com poucos dados
#     - Não sofre com curse of dimensionality (alta dimensionalidade)
#     - Suporta multiclasse naturalmente
#     - Interpretável (mostra probabilidades)
#     - Ótimo para classificação de texto
#
# - **Desvantagens:**
#     - Assume independência entre features (raramente verdadeiro)
#     - Desempenho inferior se features são correlacionadas
#     - Sensível a desbalanceamento de classes
#     - GaussianNB assume distribuição normal dos dados
#     - Problema do "zero-frequency" (palavra nunca vista)
#         - Solução: Laplace smoothing (alpha=1)
